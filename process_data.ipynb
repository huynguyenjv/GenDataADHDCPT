# %%
import pandas as pd

# %%
dt = pd.read_csv('pre-data/adhd_sample_data.csv')
dt.head()
# Out:
#   1.\tBạn thường không chú ý kỹ đến các chi tiết hoặc mắc lỗi bất cẩn trong việc học tập, làm việc hoặc trong các hoạt động khác (ví dụ: bỏ sót hoặc bỏ qua các chi tiết, công việc không chính xác).  \
# 0                                       Thường xuyên
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thường xuyên
# 4                                       Thỉnh thoảng
#
#   2. Thường gặp khó khăn trong việc duy trì sự chú ý trong các nhiệm vụ hoặc hoạt động vui chơi (ví dụ: gặp khó khăn trong việc tập trung trong khi nghe giảng, trò chuyện hoặc đọc sách dài).  \
# 0                                       Thường xuyên
# 1                                       Thỉnh thoảng
# 2                                       Thỉnh thoảng
# 3                                           Hiếm khi
# 4                                       Thường xuyên
#
#   3.\tThường có vẻ không lắng nghe khi được nói chuyện trực tiếp (ví dụ, tâm trí dường như ở nơi khác, ngay cả khi không có bất kỳ sự xao lãng rõ ràng nào).  \
# 0                                       Thường xuyên
# 1                                       Thường xuyên
# 2                                       Thỉnh thoảng
# 3                                       Thường xuyên
# 4                                      Không bao giờ
#
#   4.\tThường không làm theo hướng dẫn và không hoàn thành bài tập ở trường, công việc nhà hoặc nhiệm vụ ở nơi làm việc (ví dụ: bắt đầu làm việc nhưng nhanh chóng mất tập trung và dễ bị phân tâm).  \
# 0                                       Thỉnh thoảng
# 1                                       Thỉnh thoảng
# 2                                      Không bao giờ
# 3                                       Thường xuyên
# 4                                       Thường xuyên
#
#   5.\tThường gặp khó khăn trong việc tổ chức các nhiệm vụ và hoạt động (ví dụ: khó khăn trong việc quản lý các nhiệm vụ theo trình tự; khó khăn trong việc sắp xếp vật liệu và đồ đạc theo thứ tự; công việc lộn xộn, thiếu tổ chức; quản lý thời gian kém; không đáp ứng được thời hạn).  \
# 0                                       Thỉnh thoảng
# 1                                       Thỉnh thoảng
# 2                                      Không bao giờ
# 3                                       Thường xuyên
# 4                                           Hiếm khi
#
#   6.\tThường tránh né, không thích hoặc miễn cưỡng tham gia vào các nhiệm vụ đòi hỏi nỗ lực tinh thần liên tục (ví dụ: bài tập ở trường hoặc bài tập về nhà; đối với thanh thiếu niên lớn hơn và người lớn, là chuẩn bị báo cáo, hoàn thành biểu mẫu, xem xét các bài viết dài).  \
# 0                                       Thỉnh thoảng
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thường xuyên
# 4                                           Hiếm khi
#
#   7.\tThường làm mất những đồ dùng cần thiết cho công việc hoặc hoạt động (ví dụ: đồ dùng học tập, bút chì, sách, dụng cụ, ví, chìa khóa, giấy tờ, kính mắt, điện thoại di động).  \
# 0                                      Không bao giờ
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thường xuyên
# 4                                       Thường xuyên
#
#   8.\tThường dễ bị phân tâm bởi các kích thích bên ngoài (đối với thanh thiếu niên lớn tuổi và người lớn, có thể bao gồm những suy nghĩ không liên quan).  \
# 0                                       Thỉnh thoảng
# 1                                       Thỉnh thoảng
# 2                                       Thường xuyên
# 3                                       Thỉnh thoảng
# 4                                       Thường xuyên
#
#   9.\tThường hay quên trong các hoạt động hàng ngày (ví dụ như làm việc nhà, chạy việc vặt; đối với thanh thiếu niên lớn tuổi và người lớn, là quên gọi điện thoại, thanh toán hóa đơn, giữ đúng lịch hẹn).10.\tThường xuyên ngọ nguậy hoặc gõ tay, gõ chân hoặc ngọ nguậy trên ghế.  \
# 0                                           Hiếm khi
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thường xuyên
# 4                                           Hiếm khi
#
#   11.\tThường rời khỏi chỗ ngồi trong những tình huống mà người ta yêu cầu phải ngồi yên (ví dụ: rời khỏi chỗ trong lớp học, trong văn phòng hoặc nơi làm việc khác hoặc trong những tình huống khác đòi hỏi phải ngồi yên).  \
# 0                                       Thỉnh thoảng
# 1                                           Hiếm khi
# 2                                       Thỉnh thoảng
# 3                                       Thỉnh thoảng
# 4                                       Thường xuyên
#
#   12.\tThường chạy nhảy hoặc leo trèo trong những tình huống không phù hợp. (Lưu ý: Ở thanh thiếu niên hoặc người lớn, có thể chỉ giới hạn ở cảm giác bồn chồn).  \
# 0                                           Hiếm khi
# 1                                       Thỉnh thoảng
# 2                                       Thường xuyên
# 3                                       Thỉnh thoảng
# 4                                       Thỉnh thoảng
#
#   13.\tThường không thể chơi hoặc tham gia các hoạt động giải trí một cách yên tĩnh.  \
# 0                                       Thường xuyên
# 1                                       Thường xuyên
# 2                                       Thỉnh thoảng
# 3                                       Thường xuyên
# 4                                       Thường xuyên
#
#   14.\tThường “luôn di chuyển” như thể “được điều khiển bằng động cơ” (ví dụ: không thể hoặc không thoải mái khi phải ngồi yên trong thời gian dài, như trong nhà hàng, cuộc họp; người khác có thể cảm thấy bồn chồn hoặc khó theo kịp).  \
# 0                                      Không bao giờ
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thỉnh thoảng
# 4                                       Thường xuyên
#
#   15.\tThường nói quá nhiều.  \
# 0                   Hiếm khi
# 1               Thường xuyên
# 2               Thỉnh thoảng
# 3               Thường xuyên
# 4               Thường xuyên
#
#   16.\tThường buột miệng trả lời trước khi câu hỏi được hoàn tất (ví dụ: hoàn thành câu của người khác; không thể chờ đến lượt mình trong cuộc trò chuyện).  \
# 0                                       Thường xuyên
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thường xuyên
# 4                                           Hiếm khi
#
#   17.\tThường gặp khó khăn khi phải chờ đến lượt mình (ví dụ như khi xếp hàng).  \
# 0                                       Thường xuyên
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thường xuyên
# 4                                       Thường xuyên
#
#   18.\tThường xuyên ngắt lời hoặc xen vào việc của người khác (ví dụ: xen vào cuộc trò chuyện, trò chơi hoặc hoạt động; có thể bắt đầu sử dụng đồ của người khác mà không xin phép hoặc không được phép; đối với thanh thiếu niên và người lớn, có thể xen vào hoặc chiếm mất việc của người khác).  \
# 0                                           Hiếm khi
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thường xuyên
# 4                                       Thường xuyên
#
#      Họ và tên  Độ tuổi
# 0    Lê Minh C       22
# 1   Trần Thị Q       22
# 2  Bùi Quang G       16
# 3     Đỗ Thị F       20
# 4   Trần Thị Q       20

# %%
columns_to_check = ['Họ và tên']
for column in columns_to_check:
    if column in dt.columns:
        dt = dt.drop(columns=column, errors='ignore')
dt.head()
# Out:
#   1.\tBạn thường không chú ý kỹ đến các chi tiết hoặc mắc lỗi bất cẩn trong việc học tập, làm việc hoặc trong các hoạt động khác (ví dụ: bỏ sót hoặc bỏ qua các chi tiết, công việc không chính xác).  \
# 0                                       Thường xuyên
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thường xuyên
# 4                                       Thỉnh thoảng
#
#   2. Thường gặp khó khăn trong việc duy trì sự chú ý trong các nhiệm vụ hoặc hoạt động vui chơi (ví dụ: gặp khó khăn trong việc tập trung trong khi nghe giảng, trò chuyện hoặc đọc sách dài).  \
# 0                                       Thường xuyên
# 1                                       Thỉnh thoảng
# 2                                       Thỉnh thoảng
# 3                                           Hiếm khi
# 4                                       Thường xuyên
#
#   3.\tThường có vẻ không lắng nghe khi được nói chuyện trực tiếp (ví dụ, tâm trí dường như ở nơi khác, ngay cả khi không có bất kỳ sự xao lãng rõ ràng nào).  \
# 0                                       Thường xuyên
# 1                                       Thường xuyên
# 2                                       Thỉnh thoảng
# 3                                       Thường xuyên
# 4                                      Không bao giờ
#
#   4.\tThường không làm theo hướng dẫn và không hoàn thành bài tập ở trường, công việc nhà hoặc nhiệm vụ ở nơi làm việc (ví dụ: bắt đầu làm việc nhưng nhanh chóng mất tập trung và dễ bị phân tâm).  \
# 0                                       Thỉnh thoảng
# 1                                       Thỉnh thoảng
# 2                                      Không bao giờ
# 3                                       Thường xuyên
# 4                                       Thường xuyên
#
#   5.\tThường gặp khó khăn trong việc tổ chức các nhiệm vụ và hoạt động (ví dụ: khó khăn trong việc quản lý các nhiệm vụ theo trình tự; khó khăn trong việc sắp xếp vật liệu và đồ đạc theo thứ tự; công việc lộn xộn, thiếu tổ chức; quản lý thời gian kém; không đáp ứng được thời hạn).  \
# 0                                       Thỉnh thoảng
# 1                                       Thỉnh thoảng
# 2                                      Không bao giờ
# 3                                       Thường xuyên
# 4                                           Hiếm khi
#
#   6.\tThường tránh né, không thích hoặc miễn cưỡng tham gia vào các nhiệm vụ đòi hỏi nỗ lực tinh thần liên tục (ví dụ: bài tập ở trường hoặc bài tập về nhà; đối với thanh thiếu niên lớn hơn và người lớn, là chuẩn bị báo cáo, hoàn thành biểu mẫu, xem xét các bài viết dài).  \
# 0                                       Thỉnh thoảng
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thường xuyên
# 4                                           Hiếm khi
#
#   7.\tThường làm mất những đồ dùng cần thiết cho công việc hoặc hoạt động (ví dụ: đồ dùng học tập, bút chì, sách, dụng cụ, ví, chìa khóa, giấy tờ, kính mắt, điện thoại di động).  \
# 0                                      Không bao giờ
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thường xuyên
# 4                                       Thường xuyên
#
#   8.\tThường dễ bị phân tâm bởi các kích thích bên ngoài (đối với thanh thiếu niên lớn tuổi và người lớn, có thể bao gồm những suy nghĩ không liên quan).  \
# 0                                       Thỉnh thoảng
# 1                                       Thỉnh thoảng
# 2                                       Thường xuyên
# 3                                       Thỉnh thoảng
# 4                                       Thường xuyên
#
#   9.\tThường hay quên trong các hoạt động hàng ngày (ví dụ như làm việc nhà, chạy việc vặt; đối với thanh thiếu niên lớn tuổi và người lớn, là quên gọi điện thoại, thanh toán hóa đơn, giữ đúng lịch hẹn).10.\tThường xuyên ngọ nguậy hoặc gõ tay, gõ chân hoặc ngọ nguậy trên ghế.  \
# 0                                           Hiếm khi
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thường xuyên
# 4                                           Hiếm khi
#
#   11.\tThường rời khỏi chỗ ngồi trong những tình huống mà người ta yêu cầu phải ngồi yên (ví dụ: rời khỏi chỗ trong lớp học, trong văn phòng hoặc nơi làm việc khác hoặc trong những tình huống khác đòi hỏi phải ngồi yên).  \
# 0                                       Thỉnh thoảng
# 1                                           Hiếm khi
# 2                                       Thỉnh thoảng
# 3                                       Thỉnh thoảng
# 4                                       Thường xuyên
#
#   12.\tThường chạy nhảy hoặc leo trèo trong những tình huống không phù hợp. (Lưu ý: Ở thanh thiếu niên hoặc người lớn, có thể chỉ giới hạn ở cảm giác bồn chồn).  \
# 0                                           Hiếm khi
# 1                                       Thỉnh thoảng
# 2                                       Thường xuyên
# 3                                       Thỉnh thoảng
# 4                                       Thỉnh thoảng
#
#   13.\tThường không thể chơi hoặc tham gia các hoạt động giải trí một cách yên tĩnh.  \
# 0                                       Thường xuyên
# 1                                       Thường xuyên
# 2                                       Thỉnh thoảng
# 3                                       Thường xuyên
# 4                                       Thường xuyên
#
#   14.\tThường “luôn di chuyển” như thể “được điều khiển bằng động cơ” (ví dụ: không thể hoặc không thoải mái khi phải ngồi yên trong thời gian dài, như trong nhà hàng, cuộc họp; người khác có thể cảm thấy bồn chồn hoặc khó theo kịp).  \
# 0                                      Không bao giờ
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thỉnh thoảng
# 4                                       Thường xuyên
#
#   15.\tThường nói quá nhiều.  \
# 0                   Hiếm khi
# 1               Thường xuyên
# 2               Thỉnh thoảng
# 3               Thường xuyên
# 4               Thường xuyên
#
#   16.\tThường buột miệng trả lời trước khi câu hỏi được hoàn tất (ví dụ: hoàn thành câu của người khác; không thể chờ đến lượt mình trong cuộc trò chuyện).  \
# 0                                       Thường xuyên
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thường xuyên
# 4                                           Hiếm khi
#
#   17.\tThường gặp khó khăn khi phải chờ đến lượt mình (ví dụ như khi xếp hàng).  \
# 0                                       Thường xuyên
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thường xuyên
# 4                                       Thường xuyên
#
#   18.\tThường xuyên ngắt lời hoặc xen vào việc của người khác (ví dụ: xen vào cuộc trò chuyện, trò chơi hoặc hoạt động; có thể bắt đầu sử dụng đồ của người khác mà không xin phép hoặc không được phép; đối với thanh thiếu niên và người lớn, có thể xen vào hoặc chiếm mất việc của người khác).  \
# 0                                           Hiếm khi
# 1                                       Thường xuyên
# 2                                       Thường xuyên
# 3                                       Thường xuyên
# 4                                       Thường xuyên
#
#    Độ tuổi
# 0       22
# 1       22
# 2       16
# 3       20
# 4       20

# %%
# Danh sách các cột đánh giá mức độ
columns = [
    "1.	Bạn thường không chú ý kỹ đến các chi tiết hoặc mắc lỗi bất cẩn trong việc học tập, làm việc hoặc trong các hoạt động khác (ví dụ: bỏ sót hoặc bỏ qua các chi tiết, công việc không chính xác).",
        "2. Thường gặp khó khăn trong việc duy trì sự chú ý trong các nhiệm vụ hoặc hoạt động vui chơi (ví dụ: gặp khó khăn trong việc tập trung trong khi nghe giảng, trò chuyện hoặc đọc sách dài).",
        "3.	Thường có vẻ không lắng nghe khi được nói chuyện trực tiếp (ví dụ, tâm trí dường như ở nơi khác, ngay cả khi không có bất kỳ sự xao lãng rõ ràng nào).",
        "4.	Thường không làm theo hướng dẫn và không hoàn thành bài tập ở trường, công việc nhà hoặc nhiệm vụ ở nơi làm việc (ví dụ: bắt đầu làm việc nhưng nhanh chóng mất tập trung và dễ bị phân tâm).",
        "5.	Thường gặp khó khăn trong việc tổ chức các nhiệm vụ và hoạt động (ví dụ: khó khăn trong việc quản lý các nhiệm vụ theo trình tự; khó khăn trong việc sắp xếp vật liệu và đồ đạc theo thứ tự; công việc lộn xộn, thiếu tổ chức; quản lý thời gian kém; không đáp ứng được thời hạn).",
        "6.	Thường tránh né, không thích hoặc miễn cưỡng tham gia vào các nhiệm vụ đòi hỏi nỗ lực tinh thần liên tục (ví dụ: bài tập ở trường hoặc bài tập về nhà; đối với thanh thiếu niên lớn hơn và người lớn, là chuẩn bị báo cáo, hoàn thành biểu mẫu, xem xét các bài viết dài).",
        "7.	Thường làm mất những đồ dùng cần thiết cho công việc hoặc hoạt động (ví dụ: đồ dùng học tập, bút chì, sách, dụng cụ, ví, chìa khóa, giấy tờ, kính mắt, điện thoại di động).",
        "8.	Thường dễ bị phân tâm bởi các kích thích bên ngoài (đối với thanh thiếu niên lớn tuổi và người lớn, có thể bao gồm những suy nghĩ không liên quan).",
        "9.	Thường hay quên trong các hoạt động hàng ngày (ví dụ như làm việc nhà, chạy việc vặt; đối với thanh thiếu niên lớn tuổi và người lớn, là quên gọi điện thoại, thanh toán hóa đơn, giữ đúng lịch hẹn)."
        "10.	Thường xuyên ngọ nguậy hoặc gõ tay, gõ chân hoặc ngọ nguậy trên ghế.",
        "11.	Thường rời khỏi chỗ ngồi trong những tình huống mà người ta yêu cầu phải ngồi yên (ví dụ: rời khỏi chỗ trong lớp học, trong văn phòng hoặc nơi làm việc khác hoặc trong những tình huống khác đòi hỏi phải ngồi yên).",
        "12.	Thường chạy nhảy hoặc leo trèo trong những tình huống không phù hợp. (Lưu ý: Ở thanh thiếu niên hoặc người lớn, có thể chỉ giới hạn ở cảm giác bồn chồn).",
        "13.	Thường không thể chơi hoặc tham gia các hoạt động giải trí một cách yên tĩnh.",
        "14.	Thường “luôn di chuyển” như thể “được điều khiển bằng động cơ” (ví dụ: không thể hoặc không thoải mái khi phải ngồi yên trong thời gian dài, như trong nhà hàng, cuộc họp; người khác có thể cảm thấy bồn chồn hoặc khó theo kịp).",
        "15.	Thường nói quá nhiều.",
        "16.	Thường buột miệng trả lời trước khi câu hỏi được hoàn tất (ví dụ: hoàn thành câu của người khác; không thể chờ đến lượt mình trong cuộc trò chuyện).",
        "17.	Thường gặp khó khăn khi phải chờ đến lượt mình (ví dụ như khi xếp hàng).",
        "18.	Thường xuyên ngắt lời hoặc xen vào việc của người khác (ví dụ: xen vào cuộc trò chuyện, trò chơi hoặc hoạt động; có thể bắt đầu sử dụng đồ của người khác mà không xin phép hoặc không được phép; đối với thanh thiếu niên và người lớn, có thể xen vào hoặc chiếm mất việc của người khác)."
]


level_mapping = {
    'Không bao giờ': 1,
    'Hiếm khi': 2,
    'Thỉnh thoảng': 3,
    'Thường xuyên': 4,
}


for column in columns:
    if column in dt.columns:
        dt[column] = dt[column].map(level_mapping)

dt.to_csv('process-data/dsm5-data-process.csv', index=False)
dt.head()
# Out:
#    1.\tBạn thường không chú ý kỹ đến các chi tiết hoặc mắc lỗi bất cẩn trong việc học tập, làm việc hoặc trong các hoạt động khác (ví dụ: bỏ sót hoặc bỏ qua các chi tiết, công việc không chính xác).  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    2. Thường gặp khó khăn trong việc duy trì sự chú ý trong các nhiệm vụ hoặc hoạt động vui chơi (ví dụ: gặp khó khăn trong việc tập trung trong khi nghe giảng, trò chuyện hoặc đọc sách dài).  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  2
# 4                                                  4
#
#    3.\tThường có vẻ không lắng nghe khi được nói chuyện trực tiếp (ví dụ, tâm trí dường như ở nơi khác, ngay cả khi không có bất kỳ sự xao lãng rõ ràng nào).  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  1
#
#    4.\tThường không làm theo hướng dẫn và không hoàn thành bài tập ở trường, công việc nhà hoặc nhiệm vụ ở nơi làm việc (ví dụ: bắt đầu làm việc nhưng nhanh chóng mất tập trung và dễ bị phân tâm).  \
# 0                                                  3
# 1                                                  3
# 2                                                  1
# 3                                                  4
# 4                                                  4
#
#    5.\tThường gặp khó khăn trong việc tổ chức các nhiệm vụ và hoạt động (ví dụ: khó khăn trong việc quản lý các nhiệm vụ theo trình tự; khó khăn trong việc sắp xếp vật liệu và đồ đạc theo thứ tự; công việc lộn xộn, thiếu tổ chức; quản lý thời gian kém; không đáp ứng được thời hạn).  \
# 0                                                  3
# 1                                                  3
# 2                                                  1
# 3                                                  4
# 4                                                  2
#
#    6.\tThường tránh né, không thích hoặc miễn cưỡng tham gia vào các nhiệm vụ đòi hỏi nỗ lực tinh thần liên tục (ví dụ: bài tập ở trường hoặc bài tập về nhà; đối với thanh thiếu niên lớn hơn và người lớn, là chuẩn bị báo cáo, hoàn thành biểu mẫu, xem xét các bài viết dài).  \
# 0                                                  3
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  2
#
#    7.\tThường làm mất những đồ dùng cần thiết cho công việc hoặc hoạt động (ví dụ: đồ dùng học tập, bút chì, sách, dụng cụ, ví, chìa khóa, giấy tờ, kính mắt, điện thoại di động).  \
# 0                                                  1
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    8.\tThường dễ bị phân tâm bởi các kích thích bên ngoài (đối với thanh thiếu niên lớn tuổi và người lớn, có thể bao gồm những suy nghĩ không liên quan).  \
# 0                                                  3
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    9.\tThường hay quên trong các hoạt động hàng ngày (ví dụ như làm việc nhà, chạy việc vặt; đối với thanh thiếu niên lớn tuổi và người lớn, là quên gọi điện thoại, thanh toán hóa đơn, giữ đúng lịch hẹn).10.\tThường xuyên ngọ nguậy hoặc gõ tay, gõ chân hoặc ngọ nguậy trên ghế.  \
# 0                                                  2
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  2
#
#    11.\tThường rời khỏi chỗ ngồi trong những tình huống mà người ta yêu cầu phải ngồi yên (ví dụ: rời khỏi chỗ trong lớp học, trong văn phòng hoặc nơi làm việc khác hoặc trong những tình huống khác đòi hỏi phải ngồi yên).  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    12.\tThường chạy nhảy hoặc leo trèo trong những tình huống không phù hợp. (Lưu ý: Ở thanh thiếu niên hoặc người lớn, có thể chỉ giới hạn ở cảm giác bồn chồn).  \
# 0                                                  2
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  3
#
#    13.\tThường không thể chơi hoặc tham gia các hoạt động giải trí một cách yên tĩnh.  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    14.\tThường “luôn di chuyển” như thể “được điều khiển bằng động cơ” (ví dụ: không thể hoặc không thoải mái khi phải ngồi yên trong thời gian dài, như trong nhà hàng, cuộc họp; người khác có thể cảm thấy bồn chồn hoặc khó theo kịp).  \
# 0                                                  1
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    15.\tThường nói quá nhiều.  \
# 0                           2
# 1                           4
# 2                           3
# 3                           4
# 4                           4
#
#    16.\tThường buột miệng trả lời trước khi câu hỏi được hoàn tất (ví dụ: hoàn thành câu của người khác; không thể chờ đến lượt mình trong cuộc trò chuyện).  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  2
#
#    17.\tThường gặp khó khăn khi phải chờ đến lượt mình (ví dụ như khi xếp hàng).  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    18.\tThường xuyên ngắt lời hoặc xen vào việc của người khác (ví dụ: xen vào cuộc trò chuyện, trò chơi hoặc hoạt động; có thể bắt đầu sử dụng đồ của người khác mà không xin phép hoặc không được phép; đối với thanh thiếu niên và người lớn, có thể xen vào hoặc chiếm mất việc của người khác).  \
# 0                                                  2
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    Độ tuổi
# 0       22
# 1       22
# 2       16
# 3       20
# 4       20
